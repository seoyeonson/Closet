# %%
import json
import numpy as np

# %%
filepath = './train_data/민원(콜센터) 질의응답_K쇼핑_배송_Training.json'
with open(filepath, 'r') as f:

    json_data = json.load(f)

print(json.dumps(json_data) )
a_del=[]
for i in range(len(json_data)):
    if json_data[i]['화자'] == '고객' and json_data[i]['고객의도'] != '':
        a_del.append({'의도':json_data[i]['고객의도'].strip(),'문장':json_data[i]['고객질문(요청)'].strip(),'개체명':json_data[i]['개체명 '].strip()}) 
#     elif json_data[i]['화자'] == '고객' and json_data[i]['고객답변'] != '':
#         a_del.append({'의도':json_data[i]['고객의도'].strip(),'문장':json_data[i]['고객답변'].strip(),'개체명':json_data[i]['개체명 '].strip()}) 
#     else:
#         continue
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
a_del
# Out:
# [{'의도': '배송지오류문의',
#   '문장': '어제 유산균을 주문했는데요. 주소를 보니까 주소가 안맞아요.',
#   '개체명': '어제, 유산균, 주문, 주소'},
#  {'의도': '자동주문연결', '문장': '네, 제가 자동 주문하다가 연결이 되었거든요.', '개체명': '자동 주문, 연결'},
#  {'의도': '주소지변경문의',
#   '문장': '아, 그런가요? 주문하고 주소지 변경하고 있었거든요. 등록이 안되었나 보네요.',
#   '개체명': '주문, 주소지, 변경, 등록'},
#  {'의도': '일시불결제요청', '문장': '아니요, 그냥 일시불로 할게요.', '개체명': '일시불'},
#  {'의도': '주문신청확인', '문장': '네 안녕하세요. 방송중인 마스크 주문하려고요.', '개체명': '방송, 마스크, 주문'},
#  {'의도': '방송상품문의', '문장': '지금 선전하는 거 확인하고 싶은데요.', '개체명': '선전, 확인'},
#  {'의도': '방송상품주문', '문장': '내가 그거 하나 신청하려고요.', '개체명': '하나, 신청'},
#  {'의도': '주소변경요청확인',
#   '문장': '아, 제가 어제 미마 마스크 주문을 두 차례 걸쳐서 했는데 상담하면서 우리 집 주소가 바뀌었다고 요청을 했어요.',
#   '개체명': '어제, 미마 마스크, 주문, 두 차례, 상담, 우리 집, 주소, 요청'},
#  {'의도': '주소변경확인',
#   '문장': '새 주소로 해주세요 하고 상담사한테 요청하고 그 분도 정정을 해서 주문을 받으셨어요.',
#   '개체명': '새 주소, 상담사, 요청, 정정, 주문'},
#  {'의도': '배송지주소오류확인',
#   '문장': '그리고 나서 내가 두 번째 주문을 했는데 다른 분이 받으셨고 오늘 카카오 톡으로  메시지가 왔는데 하나는 새로 입력된 주소로 오고 다른 하나는 예전 주소로 입력이 돼서 왔어요.',
# ...

# %%
len(a_del)
# Out:
# 10678

# %%
filepath = './train_data/민원(콜센터) 질의응답_K쇼핑_배송_Training.json'
with open(filepath, 'r') as f:

    json_data = json.load(f)

print(json.dumps(json_data) )
a_del=[]
for i in range(len(json_data)):
    if json_data[i]['화자'] == '고객' and json_data[i]['고객의도'] != '':
        a_del.append({'의도':json_data[i]['고객의도'].strip(),'문장':json_data[i]['고객질문(요청)'].strip(),'개체명':json_data[i]['개체명 '].strip()}) 

filepath = './train_data/민원(콜센터) 질의응답_K쇼핑_AS_Training.json'
with open(filepath, 'r') as f:

    json_data = json.load(f)


a_shop=[]
for i in range(len(json_data)):
    if json_data[i]['화자'] == '고객' and json_data[i]['고객의도'] != '':
        a_del.append({'의도':json_data[i]['고객의도'].strip(),'문장':json_data[i]['고객질문(요청)'].strip(),'개체명':json_data[i]['개체명 '].strip()}) 

filepath = './train_data/민원(콜센터) 질의응답_K쇼핑_결제_Training.json'
with open(filepath, 'r') as f:

    json_data = json.load(f)


a_pay=[]
for i in range(len(json_data)):
    if json_data[i]['화자'] == '고객' and json_data[i]['고객의도'] != '':
        a_del.append({'의도':json_data[i]['고객의도'].strip(),'문장':json_data[i]['고객질문(요청)'].strip(),'개체명':json_data[i]['개체명 '].strip()}) 
 

filepath = './train_data/민원(콜센터) 질의응답_K쇼핑_교환_Training.json'
with open(filepath, 'r') as f:

    json_data = json.load(f)


a_chan=[]
for i in range(len(json_data)):
    if json_data[i]['화자'] == '고객' and json_data[i]['고객의도'] != '':
        a_del.append({'의도':json_data[i]['고객의도'].strip(),'문장':json_data[i]['고객질문(요청)'].strip(),'개체명':json_data[i]['개체명 '].strip()}) 

 
filepath = './train_data/민원(콜센터) 질의응답_K쇼핑_반품_Training.json'
with open(filepath, 'r') as f:

    json_data = json.load(f)


a_re=[]
for i in range(len(json_data)):
    if json_data[i]['화자'] == '고객' and json_data[i]['고객의도'] != '':
        a_del.append({'의도':json_data[i]['고객의도'].strip(),'문장':json_data[i]['고객질문(요청)'].strip(),'개체명':json_data[i]['개체명 '].strip()}) 
  

filepath = './train_data/민원(콜센터) 질의응답_K쇼핑_업무처리_Training.json'
with open(filepath, 'r') as f:

    json_data = json.load(f)


a_task=[]
for i in range(len(json_data)):
    if json_data[i]['화자'] == '고객' and json_data[i]['고객의도'] != '':
        a_del.append({'의도':json_data[i]['고객의도'].strip(),'문장':json_data[i]['고객질문(요청)'].strip(),'개체명':json_data[i]['개체명 '].strip()}) 
filepath = './train_data/민원(콜센터) 질의응답_K쇼핑_주문_Training.json'
with open(filepath, 'r') as f:

    json_data = json.load(f)


a_order=[]
for i in range(len(json_data)):
    if json_data[i]['화자'] == '고객' and json_data[i]['고객의도'] != '':
        a_del.append({'의도':json_data[i]['고객의도'].strip(),'문장':json_data[i]['고객질문(요청)'].strip(),'개체명':json_data[i]['개체명 '].strip()})
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
a =[]
a.extend(a_chan)                                      # a 라는 빈 list에 각각의 json 파일들 추가
a.extend(a_task)
a.extend(a_order)
a.extend(a_re)
a.extend(a_del)
a.extend(a_pay)
a.extend(a_shop)

a_bool = []
for i in range(len(a)):
    if (
       a[i]['의도'] == '상품가격문의'         # 특정의도만 True로 분류 해서 boolean mask 생성
        or a[i]['의도'] =='상품주문'
        or a[i]['의도'] =='상품색상문의'
        or a[i]['의도'] =='상품사이즈문의'
        or a[i]['의도'] =='배송일정확인'
        or a[i]['의도'] =='반품요청'
        or a[i]['의도'] =='주문취소요청'
        or a[i]['의도'] =='할인적용문의'


    ):
        a_bool.append(1)
    else:
        a_bool.append(0)
        
import numpy as np 
arr_bool = np.array(a_bool)        # boolean mask list -> array
a_arr = np.array(a)                # a   list -> array
train_data = a_arr[arr_bool==True]
len(train_data)
# Out:
# 5698

# %%
import pandas as pd
df = pd.read_excel('./train_data/B 의류(15,826)_new.xlsx')
df
# Out:
#       SPEAKER                  SENTENCE DOMAINID DOMAIN CATEGORY  SPEAKERID  \
# 0          고객          신발은 여기 있는 게 다예요?        B  의복의류점       신발          1
# 1          점원           네 성인이나 아동 다 있어요        B  의복의류점       신발          0
# 2          점원             발 사이즈 몇 신으세요?        B  의복의류점       신발          0
# 3          고객                     230이요        B  의복의류점       신발          1
# 4          점원       편하게 신을 수 있는 거 찾으세요?        B  의복의류점       신발          0
# ...       ...                       ...      ...    ...      ...        ...
# 15821      고객              이 쿠폰에 적립해주세요        B  의복의류점     액세서리          1
# 15822      고객   사은품 받으려면 쿠폰 몇 개 모아야 해요?        B  의복의류점     액세서리          1
# 15823      고객  쿠폰 몇 개 모으면 사은품 받을 수 있어요?        B  의복의류점     액세서리          1
# 15824      고객  쿠폰 몇 장 모아야 사은품 받을 수 있나요?        B  의복의류점     액세서리          1
# 15825      고객   사은품 받으려면 쿠폰 몇 장 있어야 돼요?        B  의복의류점     액세서리          1
#
# ...

# %%
df_1=[]
for i in range(len(df)):
    if df.iloc[i]['SPEAKER'] == '고객':
        df_1.append(df.iloc[i])
pd.DataFrame(df_1)
# Out:
#       SPEAKER                  SENTENCE DOMAINID DOMAIN CATEGORY  SPEAKERID  \
# 0          고객          신발은 여기 있는 게 다예요?        B  의복의류점       신발          1
# 3          고객                     230이요        B  의복의류점       신발          1
# 5          고객      네 봄이니까 편하게 신을 수 있는 거        B  의복의류점       신발          1
# 7          고객             굽 좀 높은 거 없나요?        B  의복의류점       신발          1
# 9          고객                  언제 들어와요?        B  의복의류점       신발          1
# ...       ...                       ...      ...    ...      ...        ...
# 15821      고객              이 쿠폰에 적립해주세요        B  의복의류점     액세서리          1
# 15822      고객   사은품 받으려면 쿠폰 몇 개 모아야 해요?        B  의복의류점     액세서리          1
# 15823      고객  쿠폰 몇 개 모으면 사은품 받을 수 있어요?        B  의복의류점     액세서리          1
# 15824      고객  쿠폰 몇 장 모아야 사은품 받을 수 있나요?        B  의복의류점     액세서리          1
# 15825      고객   사은품 받으려면 쿠폰 몇 장 있어야 돼요?        B  의복의류점     액세서리          1
#
# ...

# %%
df_ch =pd.DataFrame(df_1)[['SENTENCE','개체명','MAIN']] # 3가지의 변수만 골라서 새로운 df에 저장
df_ch.columns = ['문장','개체명','의도']  # column 명 변경

# %%
df_ch
# Out:
#                              문장     개체명           의도
# 0              신발은 여기 있는 게 다예요?  신발, 여기  종류별신발제품문의요청
# 3                         230이요     230  종류별신발제품문의요청
# 5          네 봄이니까 편하게 신을 수 있는 거       봄          착화감
# 7                 굽 좀 높은 거 없나요?       굽        굽높이문의
# 9                      언제 들어와요?      언제        재입고문의
# ...                         ...     ...          ...
# 15821              이 쿠폰에 적립해주세요     NaN      쿠폰시적립요청
# 15822   사은품 받으려면 쿠폰 몇 개 모아야 해요?     NaN    쿠폰적용사음품문의
# 15823  쿠폰 몇 개 모으면 사은품 받을 수 있어요?     NaN    쿠폰적용사음품문의
# 15824  쿠폰 몇 장 모아야 사은품 받을 수 있나요?     NaN    쿠폰적용사음품문의
# 15825   사은품 받으려면 쿠폰 몇 장 있어야 돼요?     NaN    쿠폰적용사음품문의
#
# [8381 rows x 3 columns]

# %%
# df_intent = []                 
# for i in range(len(df_ch)):
#     df_intent.append(df_ch[['의도']].iloc[i][0])  
# df_intent

# %%
df_ch_1 = pd.DataFrame(df_ch,columns=['문장','개체명','의도']).reset_index(drop=True)  # 고객만 있는 df로 index까지 수정
df_ch_1
# Out:
#                             문장     개체명           의도
# 0             신발은 여기 있는 게 다예요?  신발, 여기  종류별신발제품문의요청
# 1                        230이요     230  종류별신발제품문의요청
# 2         네 봄이니까 편하게 신을 수 있는 거       봄          착화감
# 3                굽 좀 높은 거 없나요?       굽        굽높이문의
# 4                     언제 들어와요?      언제        재입고문의
# ...                        ...     ...          ...
# 8376              이 쿠폰에 적립해주세요     NaN      쿠폰시적립요청
# 8377   사은품 받으려면 쿠폰 몇 개 모아야 해요?     NaN    쿠폰적용사음품문의
# 8378  쿠폰 몇 개 모으면 사은품 받을 수 있어요?     NaN    쿠폰적용사음품문의
# 8379  쿠폰 몇 장 모아야 사은품 받을 수 있나요?     NaN    쿠폰적용사음품문의
# 8380   사은품 받으려면 쿠폰 몇 장 있어야 돼요?     NaN    쿠폰적용사음품문의
#
# [8381 rows x 3 columns]

# %%
df_ex_dict =[]                      # 의도 문장 개체명으로 dict로 이루어진 array리스트 생성
for i in range(len(df_ch_1)):
    if df_ch_1.iloc[i].isna().sum() > 0  : # na가 없는 것 만 list에 추가
        continue
    else:
        df_ex_dict.append({'의도':df_ch_1.iloc[i][2], '문장':df_ch_1.iloc[i][0], '개체명': df_ch_1.iloc[i][1] })
df_ex_dict
# Out:
# [{'의도': '종류별신발제품문의요청', '문장': '신발은 여기 있는 게 다예요?', '개체명': '신발, 여기'},
#  {'의도': '종류별신발제품문의요청', '문장': '230이요', '개체명': 230},
#  {'의도': '착화감', '문장': '네 봄이니까 편하게 신을 수 있는 거', '개체명': '봄'},
#  {'의도': '굽높이문의', '문장': '굽 좀 높은 거 없나요?', '개체명': '굽'},
#  {'의도': '재입고문의', '문장': '언제 들어와요?', '개체명': '언제'},
#  {'의도': '소재문의', '문장': '이거는 가죽이에요?', '개체명': '이거, 가죽'},
#  {'의도': '제품가격문의', '문장': '가죽은 얼마예요?', '개체명': '가죽, 얼마'},
#  {'의도': '사이즈재고문의', '문장': '털 달린 거 저거는 사이즈 있어요?', '개체명': '털, 저거, 사이즈'},
#  {'의도': '종류별가방제품문의요청', '문장': '가방 매는 거 보고 있어요', '개체명': '가방'},
#  {'의도': '제품가격문의', '문장': '가격이 얼마예요?', '개체명': '가격, 얼마'},
#  {'의도': '소재를제시한제품문의', '문장': '가죽으로 된 거는 없어요?', '개체명': '가죽'},
#  {'의도': '제품가격문의', '문장': '레자는 얼마예요?', '개체명': '레자, 얼마'},
#  {'의도': '가방소재문의', '문장': '이거는 천이죠?', '개체명': '이거, 천'},
#  {'의도': '제품가격문의', '문장': '이건 얼마예요?', '개체명': '얼마'},
#  {'의도': '제품구성문의', '문장': '이거 끈은 따로 없어요?', '개체명': '이거, 끈'},
#  {'의도': '공휴일영업문의', '문장': '내일은 문 열어요?', '개체명': '내일, 문'},
#  {'의도': '공휴일영업문의', '문장': '며칠까지 휴무예요?', '개체명': '며칠, 휴무'},
# ...

# %%
a_bool=[]                             #
for i in range(len(df_ex_dict)):
#     if (df_ex_dict[i]['의도'] == '사이즈재고문의'
#       or df_ex_dict[i]['의도'] == '가격문의'
#        ):
        
    if(
        df_ex_dict[i]['의도'] == '가격문의'    # 상품가격문의
        or df_ex_dict[i]['의도'] == '결제요청'  # 상품주문?
        or df_ex_dict[i]['의도'] == '고객변심에의한환불/반품/교환요청'  # 반품요청  / 환불 , 교환 삭제요망
        or df_ex_dict[i]['의도'] == '고객사이즈제시에따른제품선택문의'   # 상품 사이즈 문의
        or df_ex_dict[i]['의도'] == '교환/환불가능기간문의'            # 반품가능문의?
        or df_ex_dict[i]['의도'] == '구매제품할인문의'   # 할인적용문의
        or df_ex_dict[i]['의도'] == '동제품타사이즈문의'      # 상품사이즈문의  ????
        or df_ex_dict[i]['의도'] == '동제품타색상문의'        # 상품 색상 문의 ????
        or df_ex_dict[i]['의도'] == '디자인별제품추천요청'    # 제품추천요청
        or df_ex_dict[i]['의도'] == '베스트상품문의'        # 제품 추천 요청
        or df_ex_dict[i]['의도'] == '보조제품추천요청'      # 제품 추천요청       

        or df_ex_dict[i]['의도'] == '사이즈문의'               # 상품사이즈문의
#         or df_ex_dict[i]['의도'] == '사이즈재고문의'          #  상품사이즈문의  재고는?????
        or df_ex_dict[i]['의도'] == '색상문의'                  # 상품 색상 문의
        or df_ex_dict[i]['의도'] == '색상에대한문의'         #  상품 색상 문의
#         or df_ex_dict[i]['의도'] == '신상품문의'               #  제품추천요청(신상품)
#         or df_ex_dict[i]['의도'] == '신상품입고문의'         #   신상품언제들어와요??
#         or df_ex_dict[i]['의도'] == '원하는제품재고여부확인'       # 문장 광범위 검토필
#         or df_ex_dict[i]['의도'] == '유사제품추천문의'         #  제품추천요청 ? 사이즈문의? 색상문의?
#         or df_ex_dict[i]['의도'] == '유사제품추천요청'          #  제품추천요청 ? 사이즈문의? 색상문의? 
        or df_ex_dict[i]['의도'] == '의상에따른선택문의'         # 제품추천요청??
        or df_ex_dict[i]['의도'] == '인기색상문의'              #상품 색상문의
        or df_ex_dict[i]['의도'] == '인기제품문의'             # 상품추천요청
#         or df_ex_dict[i]['의도'] == '입고시연락요청')           #  재고????
#         or df_ex_dict[i]['의도'] == '재고문의')                  # 재고????
        or df_ex_dict[i]['의도'] == '제품가격대문의'             # 상품가격문의
        or df_ex_dict[i]['의도'] == '제품가격문의'          #   상품가격문의
        or df_ex_dict[i]['의도'] == '제품별색깔종류문의'           # 상품색상문의
        or df_ex_dict[i]['의도'] == '제품별추천문의'          # 제품추천요청
        or df_ex_dict[i]['의도'] == '제품사이즈문의'          # 상품사이즈문의
        or df_ex_dict[i]['의도'] == '제품제품가격문의'          #상품가격문의
        or df_ex_dict[i]['의도'] == '제품주문'                 # 상품주문
        or df_ex_dict[i]['의도'] == '제품주문문의'        # 상품주문
        or df_ex_dict[i]['의도'] == '제품주문취소'           # 주문취소요청
        or df_ex_dict[i]['의도'] == '제품추천문의'           # 제품추천요청
        or df_ex_dict[i]['의도'] == '제품주문요청'           # 제품추천요청
        or df_ex_dict[i]['의도'] == '제품하자발견시문의'          # 반품요청? 
        or df_ex_dict[i]['의도'] == '제품하자발견시요구'           # 반품요청?
        or df_ex_dict[i]['의도'] == '제품하자에대한컴플레인'         # 반품요청?
        or df_ex_dict[i]['의도'] == '치수문의'                # 상품사이즈문의
        or df_ex_dict[i]['의도'] == '할인가격문의'           # 할인적용문의
        or df_ex_dict[i]['의도'] == '할인여부문의'           # 할인적용문의
        or df_ex_dict[i]['의도'] == '할인이유문의'            # 할인적용문의 
        or df_ex_dict[i]['의도'] == '환불/반품/교환요청/문의'           # 반품요청
        or df_ex_dict[i]['의도'] == '환불반품교환가능여부문의'           # 반품요청
        or df_ex_dict[i]['의도'] == '환불반품교환문의'            # 반품요청??
        or df_ex_dict[i]['의도'] == '환불반품교환요청'          # 반품요청
        or df_ex_dict[i]['의도'] == '환불반품교환요청문의'          # 반품요청      
    ):
        a_bool.append(1)
    else:
        a_bool.append(0)
import numpy as np 
arr_bool = np.array(a_bool)        # boolean mask list -> array
a_arr = np.array(df_ex_dict)                # a   list -> array
train_data_ex = a_arr[arr_bool==True]
train_data_ex
len(train_data_ex)
# Out:
# 2530

# %%
for i in range(len(train_data_ex)):                    # 의도 통합
    if train_data_ex[i]['의도'] == '가격문의':
        train_data_ex[i]['의도'] = '상품가격문의'
    elif  train_data_ex[i]['의도'] == '결제요청':
        train_data_ex[i]['의도'] = '상품주문'
    elif  train_data_ex[i]['의도'] == '고객변심에의한환불/반품/교환요청':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '고객사이즈제시에따른제품선택문의':
        train_data_ex[i]['의도'] = '상품사이즈문의'
    elif  train_data_ex[i]['의도'] == '교환/환불가능기간문의':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '구매제품할인문의':
        train_data_ex[i]['의도'] = '할인적용문의'
    elif  train_data_ex[i]['의도'] == '동제품타사이즈문의':
        train_data_ex[i]['의도'] = '상품사이즈문의'
    elif  train_data_ex[i]['의도'] == '동제품타색상문의':
        train_data_ex[i]['의도'] = '상품색상문의'
    elif  train_data_ex[i]['의도'] == '디자인별제품추천요청':
        train_data_ex[i]['의도'] = '제품추천요청'
#     elif  train_data_ex[i]['의도'] == '디자인선택':
#         train_data_ex[i]['의도'] = ''
    elif  train_data_ex[i]['의도'] == '베스트상품문의': # 이거 의도 추가
        train_data_ex[i]['의도'] = '제품추천요청'
    elif  train_data_ex[i]['의도'] == '보조제품추천요청':
        train_data_ex[i]['의도'] = '제품추천요청'
    elif  train_data_ex[i]['의도'] == '사이즈문의':
        train_data_ex[i]['의도'] = '상품사이즈문의'
#     elif  train_data_ex[i]['의도'] == '사이즈재고문의': # 재고 의도 추가
#         train_data_ex[i]['의도'] = ''
    elif  train_data_ex[i]['의도'] == '색상문의':
        train_data_ex[i]['의도'] = '상품색상문의'
    elif  train_data_ex[i]['의도'] == '색상에대한문의':
        train_data_ex[i]['의도'] = '상품색상문의'
#     elif  train_data_ex[i]['의도'] == '신상품문의':# 신상품 관련 의도?
#         train_data_ex[i]['의도'] = '제품추천요청' 
#     elif  train_data_ex[i]['의도'] == '액세서리디자인선택': # 상품사이즈문의 (선택)
#         train_data_ex[i]['의도'] = ''
#     elif  train_data_ex[i]['의도'] == '원하는제품재고여부확인':
#         train_data_ex[i]['의도'] = ''
#     elif  train_data_ex[i]['의도'] == '유사제품추천문의':
#         train_data_ex[i]['의도'] = ''
#     elif  train_data_ex[i]['의도'] == '유사제품추천요청':
#         train_data_ex[i]['의도'] = ''
    elif  train_data_ex[i]['의도'] == '의상에따른선택문의':
        train_data_ex[i]['의도'] = '제품추천요청'
    elif  train_data_ex[i]['의도'] == '인기색상문의':
        train_data_ex[i]['의도'] = '상품색상문의'
    elif  train_data_ex[i]['의도'] == '인기제품문의':
        train_data_ex[i]['의도'] = '상품추천요청'
#     elif  train_data_ex[i]['의도'] == '입고시연락요청':  # 재고?
#         train_data_ex[i]['의도'] = ''
#     elif  train_data_ex[i]['의도'] == '재고문의':  # 재고
#         train_data_ex[i]['의도'] = ''
    elif  train_data_ex[i]['의도'] == '제품가격대문의':
        train_data_ex[i]['의도'] = '상품가격문의'
    elif  train_data_ex[i]['의도'] == '제품가격문의':
        train_data_ex[i]['의도'] = '상품가격문의'
    elif  train_data_ex[i]['의도'] == '제품별색깔종류문의':
        train_data_ex[i]['의도'] = '상품색상문의'
    elif  train_data_ex[i]['의도'] == '제품별추천문의':
        train_data_ex[i]['의도'] = '상품추천요청'
    elif  train_data_ex[i]['의도'] == '제품사이즈문의':
        train_data_ex[i]['의도'] = '상품사이즈문의'
    elif  train_data_ex[i]['의도'] == '제품제품가격문의':
        train_data_ex[i]['의도'] = '상품가격문의'
    elif  train_data_ex[i]['의도'] == '제품주문':
        train_data_ex[i]['의도'] = '상품주문'
    elif  train_data_ex[i]['의도'] == '제품주문문의':
        train_data_ex[i]['의도'] = '상품주문'
    elif  train_data_ex[i]['의도'] == '제품주문취소':
        train_data_ex[i]['의도'] = '주문취소요청'
    elif  train_data_ex[i]['의도'] == '제품추천문의':
        train_data_ex[i]['의도'] = '상품추천요청'
    elif  train_data_ex[i]['의도'] == '제품하자발견시문의':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '제품하자에대한컴플레인':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '치수문의':
        train_data_ex[i]['의도'] = '상품사이즈문의'
    elif  train_data_ex[i]['의도'] == '할인가격문의':
        train_data_ex[i]['의도'] = '할인적용문의'
    elif  train_data_ex[i]['의도'] == '할인여부문의':
        train_data_ex[i]['의도'] = '할인적용문의'
    elif  train_data_ex[i]['의도'] == '할인이유문의':
        train_data_ex[i]['의도'] = '할인적용문의'
    elif  train_data_ex[i]['의도'] == '환불/반품/교환요청/문의':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '환불반품교환가능여부문의':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '환불반품교환문의':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '환불반품교환요청':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '환불반품교환요청문의':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '고객변심에의한환불반품교환요청':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '제품하자발견시요구':
        train_data_ex[i]['의도'] = '반품요청'
    elif  train_data_ex[i]['의도'] == '제품추천요청':
        train_data_ex[i]['의도'] = '상품추천요청'
#     elif  train_data_ex[i]['의도'] == '상품가격확인':
#         train_data_ex[i]['의도'] = '상품가격문의'
#     elif  train_data_ex[i]['의도'] == '반품가능문의':
#         train_data_ex[i]['의도'] = '반품요청'
#     elif  train_data_ex[i]['의도'] == '결제금액문의':
#         train_data_ex[i]['의도'] = '상품가격문의'
#     elif  train_data_ex[i]['의도'] == '반품절차확인':
#         train_data_ex[i]['의도'] = '반품문의'



train_data_ex
# Out:
# array([{'의도': '상품가격문의', '문장': '가죽은 얼마예요?', '개체명': '가죽, 얼마'},
#        {'의도': '상품가격문의', '문장': '가격이 얼마예요?', '개체명': '가격, 얼마'},
#        {'의도': '상품가격문의', '문장': '레자는 얼마예요?', '개체명': '레자, 얼마'}, ...,
#        {'의도': '상품가격문의', '문장': '이런 스카프는 얼마예요?', '개체명': '스카프'},
#        {'의도': '상품가격문의', '문장': '이런 옷은 얼마예요?', '개체명': '옷'},
#        {'의도': '상품추천요청', '문장': '요즘 유행하는 색깔이 뭐예요?', '개체명': '유행,색깔'}],
#       dtype=object)

# %%
intent_li = list()                                  # 엑셀 데이터의 수정된 의도 확인
for i in range(len(train_data_ex)):
    intent_li.append(train_data_ex[i]['의도']) 
set(intent_li)
# Out:
# {'반품요청', '상품가격문의', '상품사이즈문의', '상품색상문의', '상품주문', '상품추천요청', '할인적용문의'}

# %%
intent_li = list()                                 # json 데이터 통합파일의 의도 확인
for i in range(len(train_data)):
    intent_li.append(train_data[i]['의도']) 
set(intent_li)
# Out:
# {'반품요청', '배송일정확인', '상품가격문의', '상품사이즈문의', '상품색상문의', '상품주문', '주문취소요청', '할인적용문의'}

# %%
len(train_data),len(train_data_ex),len(np.concatenate((train_data,train_data_ex),axis=0)) #개수 확인
# Out:
# (5698, 2530, 8228)

# %%
train_sum = np.concatenate((train_data,train_data_ex),axis=0) # 두 train 데이터 합치기

# %%
intent_li = list()                                 # 합친 데이터의 의도 개수 확인
for i in range(len(train_sum)):
    intent_li.append(train_sum[i]['의도']) 
set(intent_li)
# Out:
# {'반품요청',
#  '배송일정확인',
#  '상품가격문의',
#  '상품사이즈문의',
#  '상품색상문의',
#  '상품주문',
#  '상품추천요청',
#  '주문취소요청',
#  '할인적용문의'}

# %%
# 전처리 모듈은 챗봇 엔진 내에서 자주 사용하기 때문에 클래스로 설계 해 둡니다

from konlpy.tag import Komoran
import pickle
import jpype

class Preprocess:
    def __init__(self, word2index_dic='', userdic=None):  # 생성자 
        # 단어 인덱스 사전 불러오기
        if(word2index_dic != ''):
            f = open(word2index_dic, "rb")
            self.word_index = pickle.load(f)
            f.close()
        else:
            self.word_index = None     
    
    
        # ① 형태소 분석기 초기화
        self.komoran = Komoran(userdic=userdic)

        # ② 제외할 품사
        # 참조 : https://docs.komoran.kr/firststep/postypes.html
        # 관계언 제거, 기호 제거
        # 어미 제거
        # 접미사 제거
        self.exclusion_tags = [
            'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ',
            'JX', 'JC',
            'SF', 'SP', 'SS', 'SE', 'SO',
            'EP', 'EF', 'EC', 'ETN', 'ETM',
            'XSN', 'XSV', 'XSA'
        ]

    # ③ 형태소 분석기 POS 태거
    #  이렇게 래퍼(wrapper) 를 만들어 두면 나중에 형태소 분석기 종류를 바꾸어도 동작할수 있다. (유지보수 측면 good)
    def pos(self, sentence):
        return self.komoran.pos(sentence)

    # ④ 불용어 제거 후, 필요한 품사 정보만 가져오기
    def get_keywords(self, pos, without_tag=False):
        f = lambda x: x in self.exclusion_tags
        word_list = []
        for p in pos:
            if f(p[1]) is False:
                word_list.append(p if without_tag is False else p[0])
        return word_list  
    
    # 키워드를 단어 인덱스 시퀀스로 변환
    def get_wordidx_sequence(self, keywords):
        if self.word_index is None:
            return []

        w2i = []
        for word in keywords:
            try:
                w2i.append(self.word_index[word])
            except KeyError:
                # 해당 단어가 사전에 없는 경우, OOV 처리
                w2i.append(self.word_index['OOV'])
        return w2i

# %%
# a 말뭉치 데이터 리스트에서 문장을 하나씩 불러와 POS 테깅  (★시간걸림★)
p = Preprocess()
dict = []
cnt=0
tsv=[]
for c in np.delete(train_sum,3448,0): #문장에 이상이 있는 3448번째 문장 빼고 태깅
    pos = p.pos(c['문장'])
    for k in pos:
        dict.append(k[0])
    print(pos,cnt)
    tsv.append(pos)
    cnt += 1
# Out:
# [('음', 'IC'), (',', 'SP'), ('그러면', 'MAJ'), ('하나', 'NR'), ('하', 'VV'), ('아', 'EC'), ('주', 'VX'), ('시', 'EP'), ('어요', 'EF'), ('.', 'SF')] 0
# [('네', 'IC'), ('.', 'SF'), ('자동', 'NNG'), ('으로', 'JKB'), ('하', 'VV'), ('면', 'EC'), ('디', 'NNP'), ('씨', 'NNB'), ('되', 'VV'), ('나요', 'EF'), ('?', 'SF')] 1
# [('어떤', 'MM'), ('게', 'NNG'), ('있', 'VX'), ('나요', 'EF'), ('?', 'SF')] 2
# [('네', 'IC'), ('.', 'SF'), ('내추럴', 'NNP'), ('브라운', 'NNP'), ('이랑', 'NNP'), ('두', 'MM'), ('가지', 'NNB'), ('안', 'MAG'), ('되', 'VV'), ('나요', 'EF'), ('?', 'SF')] 3
# [('어떤', 'MM'), ('색깔', 'NNG'), ('을', 'JKO'), ('주문', 'NNG'), ('하', 'XSV'), ('아야', 'EC'), ('되', 'VV'), ('나요', 'EF'), ('?', 'SF')] 4
# [('아', 'IC'), ('.', 'SF'), ('다크', 'NNP'), ('가', 'JKS'), ('좀', 'MAG'), ('진한', 'NNP'), ('색', 'NNG'), ('이', 'VCP'), ('죠', 'EF'), ('?', 'SF')] 5
# ...

# %%
tsv[1]
# Out:
# [('네', 'IC'),
#  ('.', 'SF'),
#  ('자동', 'NNG'),
#  ('으로', 'JKB'),
#  ('하', 'VV'),
#  ('면', 'EC'),
#  ('디', 'NNP'),
#  ('씨', 'NNB'),
#  ('되', 'VV'),
#  ('나요', 'EF'),
#  ('?', 'SF')]

# %%
def simply(list):
    result=[]
    for item in list:
        result.extend(item)
    return result
tsv_sim = set(simply(tsv))

# %%
tsv_sim
# Out:
# {('변경', 'NNG'),
#  ('맞', 'VV'),
#  ('저렇', 'VA'),
#  ('흰색', 'NNG'),
#  ('박히', 'VV'),
#  ('이주', 'NNP'),
#  ('가요', 'NNP'),
#  ('센치', 'NNP'),
#  ('정제', 'NNP'),
#  ('내', 'NP'),
#  ('복잡', 'XR'),
#  ('누르', 'VV'),
#  ('까맣', 'VA'),
#  ('흑', 'NNG'),
#  ('어서요', 'EC'),
#  ('벌', 'NNG'),
#  ('스포트라이트', 'NNP'),
#  ('트레이닝', 'NNG'),
#  ('한', 'MM'),
#  ('신어', 'NNP'),
#  ('좋아하', 'VV'),
#  ('옷', 'NNG'),
#  ('네네', 'NNP'),
#  ('일', 'NNG'),
#  ('여하튼', 'MAG'),
#  ('두', 'VV'),
#  ('출발', 'NNG'),
#  ('오르', 'VV'),
#  ('ㅇㅇ쇼핑에는', 'NA'),
#  ('휴대폰', 'NNG'),
#  ('경비실', 'NNG'),
#  ('이왕이면', 'MAG'),
#  ('얼', 'NNG'),
#  ('낮', 'NNG'),
#  ('ㅂ니까', 'EF'),
#  ('여러', 'MM'),
#  ('단화', 'NNP'),
#  ('ㅇㅇㅇ요.', 'NA'),
#  ('때', 'NNG'),
#  ('오', 'NR'),
#  ('미색', 'NNG'),
#  ('ㅇㅇ세트인데요.', 'NA'),
#  ('롱코트', 'NA'),
#  ('빨리', 'MAG'),
#  ('라구요', 'EF'),
#  ('김치', 'NNG'),
#  ('이건', 'NNP'),
#  ('45', 'SN'),
#  ('포함', 'NNG'),
#  ('안와', 'NNP'),
#  ('회수', 'NNG'),
#  ('그래', 'IC'),
#  ('쓰레기', 'NNP'),
#  ('안', 'MAG'),
#  ('저', 'NP'),
# ...

# %%
from tensorflow.keras import preprocessing
import pickle
import os

# %%
tokenizer = preprocessing.text.Tokenizer(oov_token='OOV')  # 어휘에 없으면 'OOV' 로 token 대체
tokenizer.fit_on_texts(dict)
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'OOV': 1,
#  '하': 2,
#  '이': 3,
#  '는': 4,
#  '반품': 5,
#  '네': 6,
#  '아': 7,
#  '요': 8,
#  '어요': 9,
#  '은': 10,
#  '얼마': 11,
#  '되': 12,
#  '가': 13,
#  '게': 14,
#  '나요': 15,
#  '있': 16,
#  '사이즈': 17,
#  '았': 18,
#  '주문': 19,
#  '시': 20,
#  '주': 21,
#  '에': 22,
#  '을': 23,
#  'ㄴ': 24,
#  '예': 25,
#  '는데': 26,
#  '거': 27,
#  '좀': 28,
#  '고': 29,
#  'ㄴ가요': 30,
#  '이것': 31,
#  '가격': 32,
#  '죠': 33,
#  '색상': 34,
#  '안': 35,
#  '원': 36,
#  '아요': 37,
#  '그럼': 38,
#  '는데요': 39,
#  '것': 40,
#  '취소': 41,
#  '면': 42,
#  'ㄹ': 43,
#  '어떻': 44,
#  '제가': 45,
#  '를': 46,
#  '없': 47,
#  '맞': 48,
#  '어': 49,
#  '오': 50,
#  '으로': 51,
#  '아서': 52,
#  '로': 53,
#  '아니': 54,
#  '도': 55,
#  '그러면': 56,
#  '지금': 57,
#  '려고요': 58,
#  '겠': 59,
#  '만': 60,
#  '뭐': 61,
#  '할인': 62,
#  '받': 63,
#  '그': 64,
#  '상품': 65,
#  '나오': 66,
#  '크': 67,
#  'ㄹ려고': 68,
#  '같': 69,
#  '옷': 70,
#  '에요': 71,
#  '그냥': 72,
#  '아야': 73,
#  '었': 74,
#  '수': 75,
#  '그것': 76,
#  '보': 77,
#  '려고': 78,
#  '네요': 79,
#  '예요': 80,
# ...

# %%
# 생성된 단어 인덱스 딕셔너리(word_index) 객체를 파일로 저장
f = open(os.path.join('./dict',"chatbot_dict.bin"), "wb")  # binary 모드에선 encoding 옵션 필요없다
try:
    pickle.dump(word_index, f)
except Exception as e:
    print(e)
finally:
    f.close()

# %%
import pickle
import os
# 단어 사전 불러오기
f = open(os.path.join("./dict", "chatbot_dict.bin"), "rb")
word_index = pickle.load(f)
f.close()

# %%
# sent = '이 옷 가격이 왜 이렇게 싸요?'
# sent = '이걸로 주세요'
# sent = '계산해주세요'
sent = '무슨 사이즈가 있나요?'




# 전처리 객체 생성
p = Preprocess(userdic=os.path.join('./utils', 'user_dict.csv'))

# 형태소분석기 실행
pos = p.pos(sent)

# 품사 태그 없이 키워드 출력
keywords = p.get_keywords(pos, without_tag=True)
for word in keywords:
    try:
        print(word, word_index[word])
    except KeyError:
        # 해당 단어가 사전에 없는 경우, OOV 처리
        print(word, word_index['OOV'])
        
# ↓ 문장의 키워드와 그 단어에 대한 index 값 출력
# Out:
# 무슨 175
# 사이즈 17
# 있 16

# %%
sum_ex = pd.DataFrame.from_records(np.delete(train_sum,3448,0))
sum_ex.to_excel('test_sum.xlsx')

# %%
sum_ex
# Out:
#           의도                        문장            개체명
# 0       상품주문           음, 그러면 하나 해주세요.             하나
# 1     할인적용문의        네. 자동으로 하면 디씨 되나요?         자동, 디씨
# 2     상품색상문의                 어떤 게 있나요?
# 3     상품색상문의  네. 내추럴 브라운이랑 두 가지 안 되나요?  내추럴 브라운, 두 가지
# 4     상품색상문의          어떤 색깔을 주문해야 되나요?         색깔, 주문
# ...      ...                       ...            ...
# 8222  상품추천요청   요즘은 유행이 되게 단순하게 많이 나가죠?       요즘,유행,단순
# 8223  상품가격문의  블라우스나 티셔츠 같은거는 얼마부터 있어요?       블라우스,티셔츠
# 8224  상품가격문의             이런 스카프는 얼마예요?            스카프
# 8225  상품가격문의               이런 옷은 얼마예요?              옷
# 8226  상품추천요청          요즘 유행하는 색깔이 뭐예요?          유행,색깔
#
# [8227 rows x 3 columns]

# %%
sum_ex.to_excel('test_sum.xlsx')

# %%
p = Preprocess(word2index_dic=os.path.join('./dict', 'chatbot_dict.bin'),
               userdic=os.path.join('./train_data', 'train_1.tsv'))

# %%
tsv_sim = list(tsv_sim)
pd.DataFrame(tsv_sim).to_excel('tsv_sim.xlsx')
