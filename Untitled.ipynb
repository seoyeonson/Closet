# %%
# 전처리 모듈은 챗봇 엔진 내에서 자주 사용하기 때문에 클래스로 설계 해 둡니다

from konlpy.tag import Komoran
import pickle
import jpype

class Preprocess:
    def __init__(self, word2index_dic='', userdic=None):  # 생성자 
        # 단어 인덱스 사전 불러오기
        if(word2index_dic != ''):
            f = open('C:\DevRoot\TeamProj2\dict\chatbot_dict.bin', "rb")
            self.word_index = pickle.load(f)
            f.close()
        else:
            self.word_index = None     
    
    
        # ① 형태소 분석기 초기화
        self.komoran = Komoran(userdic='dict/user_dict.txt')
        # ② 제외할 품사
        # 참조 : https://docs.komoran.kr/firststep/postypes.html
        # 관계언 제거, 기호 제거
        # 어미 제거
        # 접미사 제거
        self.exclusion_tags = [
            'JKS', 'JKC', 'JKG', 'JKO', 'JKB', 'JKV', 'JKQ',
            'JX', 'JC',
            'SF', 'SP', 'SS', 'SE', 'SO',
            'EP', 'EF', 'EC', 'ETN', 'ETM',
            'XSN', 'XSV', 'XSA'
        ]

    # ③ 형태소 분석기 POS 태거
    #  이렇게 래퍼(wrapper) 를 만들어 두면 나중에 형태소 분석기 종류를 바꾸어도 동작할수 있다. (유지보수 측면 good)
    def pos(self, sentence):
        return self.komoran.pos(sentence)

    # ④ 불용어 제거 후, 필요한 품사 정보만 가져오기
    def get_keywords(self, pos, without_tag=False):
        f = lambda x: x in self.exclusion_tags
        word_list = []
        for p in pos:
            if f(p[1]) is False:
                word_list.append(p if without_tag is False else p[0])
        return word_list  
    
    # 키워드를 단어 인덱스 시퀀스로 변환
    def get_wordidx_sequence(self, keywords):
        if self.word_index is None:
            return []

        w2i = []
        for word in keywords:
            try:
                w2i.append(self.word_index[word])
            except KeyError:
                # 해당 단어가 사전에 없는 경우, OOV 처리
                w2i.append(self.word_index['OOV'])
        return w2i

# %%
import pandas as pd
df = pd.read_excel('./tsv_sim.xlsx').set_index('Unnamed: 0')
dict=[]
for i in range(len(df)):
    dict.append((df.iloc[i][0],df.iloc[i][1]))
dict
# Out:
# [('미팅', 'NNP'),
#  ('다지기', 'NNG'),
#  ('난리', 'NNG'),
#  ('전부', 'NNG'),
#  ('뒷줄', 'NNG'),
#  ('갈치', 'NNP'),
#  ('한정판', 'NNP'),
#  ('ㅇㅇ', nan),
#  ('사', 'NR'),
#  ('구', 'XPN'),
#  ('년', 'NNB'),
#  ('귀찮', 'VA'),
#  ('뱅', 'NNG'),
#  ('보고', 'JKB'),
#  ('등산화', 'NNG'),
#  ('이후', 'NNG'),
#  ('게끔', 'EC'),
#  ('보라색', 'NNG'),
#  ('원단', 'NNP'),
#  ('상', 'XSN'),
#  ('불이', 'NNP'),
#  ('소매', 'NNP'),
#  ('주중', 'NNG'),
#  ('골드', 'NNP'),
#  ('하의', 'NNP'),
#  ('단가', 'NNP'),
#  ('넣', 'VV'),
#  ('아니', 'IC'),
#  ('ㄹ려구', 'EC'),
#  ('ㄹ래요', 'EF'),
#  ('대형', 'NNG'),
#  ('뮬', nan),
#  ('상품', 'NNP'),
#  ('효과', 'NNG'),
#  ('특가', 'NNG'),
#  ('소독', 'NNG'),
#  ('라니까요', 'EF'),
#  ('조그맣', 'VA'),
#  ('노랗', 'VA'),
#  ('엉뚱', 'XR'),
#  ('사실', 'NNG'),
#  ('워싱팬츠', nan),
#  ('라이', 'NNP'),
#  ('께', 'JKB'),
#  ('프로', 'NNG'),
#  ('생기', 'VV'),
#  ('맨', 'MM'),
#  ('네', 'MM'),
#  ('보내', 'VV'),
#  ('책임지', 'VV'),
#  ('남자친구', 'NNP'),
#  ('새', 'VV'),
#  ('애매', 'XR'),
#  ('러닝', 'NNG'),
#  ('가깝', 'VA'),
#  ('실내', 'NNG'),
# ...

# %%
import numpy as np

# %%
# a 말뭉치 데이터 리스트에서 문장을 하나씩 불러와 POS 테깅  (★시간걸림★)
p = Preprocess()
dict = []
cnt=0
tsv=[]
for c in np.delete(train_sum,3448,0): #문장에 이상이 있는 3448번째 문장 빼고 태깅
    pos = p.pos(c['문장'])
    for k in pos:
        dict.append(k[0])
    print(pos,cnt)
    tsv.append(pos)
    cnt += 1
# Out:
# [('음', 'IC'), (',', 'SP'), ('그러면', 'MAJ'), ('하나', 'NR'), ('하', 'VV'), ('아', 'EC'), ('주', 'VX'), ('시', 'EP'), ('어요', 'EF'), ('.', 'SF')] 0
# [('네', 'IC'), ('.', 'SF'), ('자동', 'NNG'), ('으로', 'JKB'), ('하', 'VV'), ('면', 'EC'), ('디', 'NNP'), ('씨', 'NNB'), ('되', 'VV'), ('나요', 'EF'), ('?', 'SF')] 1
# [('어떤', 'MM'), ('게', 'NNG'), ('있', 'VX'), ('나요', 'EF'), ('?', 'SF')] 2
# [('네', 'IC'), ('.', 'SF'), ('내추럴', 'NNP'), ('브라운', 'NNP'), ('이랑', 'NNP'), ('두', 'MM'), ('가지', 'NNB'), ('안', 'MAG'), ('되', 'VV'), ('나요', 'EF'), ('?', 'SF')] 3
# [('어떤', 'MM'), ('색깔', 'NNG'), ('을', 'JKO'), ('주문', 'NNG'), ('하', 'XSV'), ('아야', 'EC'), ('되', 'VV'), ('나요', 'EF'), ('?', 'SF')] 4
# [('아', 'IC'), ('.', 'SF'), ('다크', 'NNP'), ('가', 'JKS'), ('좀', 'MAG'), ('진한', 'NNP'), ('색', 'NNG'), ('이', 'VCP'), ('죠', 'EF'), ('?', 'SF')] 5
# ...

# %%
df.iloc[0][1]
# Out:
# 'NNP'

# %%
p = Preprocess()

# %%
p.pos('레그웨어')
# Out:
# [('레그웨어', 'NNG')]

# %%
import numpy as np
train_sum = np.load('train_sum.npy',allow_pickle=True)

# %%
train_sum
# Out:
# array([{'의도': '상품주문', '문장': '음, 그러면 하나 해주세요.', '개체명': '하나'},
#        {'의도': '할인적용문의', '문장': '네. 자동으로 하면 디씨 되나요?', '개체명': '자동, 디씨'},
#        {'의도': '상품색상문의', '문장': '어떤 게 있나요?', '개체명': ''}, ...,
#        {'의도': '상품가격문의', '문장': '이런 스카프는 얼마예요?', '개체명': '스카프'},
#        {'의도': '상품가격문의', '문장': '이런 옷은 얼마예요?', '개체명': '옷'},
#        {'의도': '상품추천요청', '문장': '요즘 유행하는 색깔이 뭐예요?', '개체명': '유행,색깔'}],
#       dtype=object)

# %%
# a 말뭉치 데이터 리스트에서 문장을 하나씩 불러와 POS 테깅  (★시간걸림★)

p = Preprocess()
dict = []
cnt=0
tsv=[]
for c in np.delete(train_sum,3448,0): #문장에 이상이 있는 3448번째 문장 빼고 태깅
    pos = p.pos(c['문장'])
    for k in pos:
        dict.append(k[0])
    print(pos,cnt)
    tsv.append(pos)
    cnt += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 3>()
#       1 # a 말뭉치 데이터 리스트에서 문장을 하나씩 불러와 POS 테깅  (★시간걸림★)
# ----> 3 p = Preprocess()
#       4 dict = []
#       5 cnt=0
#
# NameError: name 'Preprocess' is not defined

# %%
dict
# Out:
# ['음',
#  ',',
#  '그러면',
#  '하나',
#  '하',
#  '아',
#  '주',
#  '시',
#  '어요',
#  '.',
#  '네',
#  '.',
#  '자동',
#  '으로',
#  '하',
#  '면',
#  '디',
#  '씨',
#  '되',
#  '나요',
#  '?',
#  '어떤',
#  '게',
#  '있',
#  '나요',
#  '?',
#  '네',
#  '.',
#  '내추럴',
#  '브라운',
#  '이랑',
#  '두',
#  '가지',
#  '안',
#  '되',
#  '나요',
#  '?',
#  '어떤',
#  '색깔',
#  '을',
#  '주문',
#  '하',
#  '아야',
#  '되',
#  '나요',
#  '?',
#  '아',
#  '.',
#  '다크',
#  '가',
#  '좀',
#  '진한',
#  '색',
#  '이',
#  '죠',
#  '?',
#  '제가',
#  '프라이팬',
#  '으로',
#  '착각',
#  '하',
#  '았',
#  '지만',
#  '이',
#  '상품',
#  '박스',
#  '채',
#  '그대로',
#  '이',
#  '라',
#  '반품',
#  '하',
#  '아',
#  '주',
#  '시',
#  '어요',
#  '.',
#  '그것',
#  '같',
#  '은',
#  '가격',
#  '에',
#  '살',
#  'ㄹ',
#  '수',
#  '있',
#  '어요',
#  '?',
#  '네',
#  ',',
#  '주문',
#  '은',
#  '맞',
#  '는데',
#  '취소',
#  '하',
#  'ㄹ려고',
#  '요',
#  '.',
#  '내',
#  '가',
#  '삼십',
#  '육',
#  '이',
#  '니까',
#  '.',
#  '네',
#  '.',
#  '사',
#  '만',
#  '팔천',
#  '구백',
#  '원',
#  '아니',
#  'ㅂ니까',
#  '?',
#  '바닥',
#  '에',
# ...

# %%
from tensorflow.keras import preprocessing
import pickle
import os

# %%
tokenizer = preprocessing.text.Tokenizer(oov_token='OOV')  # 어휘에 없으면 'OOV' 로 token 대체
tokenizer.fit_on_texts(dict)
word_index = tokenizer.word_index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 tokenizer = preprocessing.text.Tokenizer(oov_token='OOV')  # 어휘에 없으면 'OOV' 로 token 대체
# ----> 2 tokenizer.fit_on_texts(dict)
#       3 word_index = tokenizer.word_index
#
# File C:\ProgramData\Anaconda3\envs\data118\lib\site-packages\keras_preprocessing\text.py:212, in Tokenizer.fit_on_texts(self, texts)
#     199 def fit_on_texts(self, texts):
#     200     """Updates internal vocabulary based on a list of texts.
#     201
#     202     In the case where texts contains lists,
#    (...)
#     210             or a list of list of strings.
#     211     """
# --> 212     for text in texts:
#     213         self.document_count += 1
#     214         if self.char_level or isinstance(text, list):
#
# TypeError: 'type' object is not iterable

# %%
word_index['아우터'] = 2420
word_index['책'] =2421
word_index['음악'] =2422
word_index['티켓'] =2423
word_index['뷰티'] =2424
word_index['스커트'] =2425
word_index['취미'] =2426
word_index['예술'] =2427
word_index['레그웨어'] =2428
word_index['선글라스'] =2429
word_index['안경테'] =2430

# %%
from PyKomoran import *

komoran = Komoran(DEFAULT_MODEL['FULL'])
komoran.set_user_dic('dict/user_dict.txt')

# %%
print(komoran.get_plain_text('상의'))
# Out:
# 상의/NNG

# %%
#상의NNG 아우터NNG 레그웨어NNG

# %%
p.get_wordidx_sequence('응')
# Out:
# []

# %%
from PyKomoran import *
komoran = Komoran()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 from PyKomoran import *
# ----> 2 komoran = Komoran()
#
# TypeError: __init__() missing 1 required positional argument: 'model_path'

# %%
with open('C:\DevRoot\TeamProj2\dict\chatbot_dict.bin', "rb") as f:
    word_index = pickle.load(f)
    f.close()

# %%
word_index
# Out:
# {'OOV': 1,
#  '하': 2,
#  '이': 3,
#  '는': 4,
#  '반품': 5,
#  '네': 6,
#  '아': 7,
#  '요': 8,
#  '어요': 9,
#  '은': 10,
#  '얼마': 11,
#  '되': 12,
#  '가': 13,
#  '게': 14,
#  '나요': 15,
#  '있': 16,
#  '사이즈': 17,
#  '았': 18,
#  '주문': 19,
#  '시': 20,
#  '주': 21,
#  '에': 22,
#  '을': 23,
#  'ㄴ': 24,
#  '예': 25,
#  '는데': 26,
#  '거': 27,
#  '좀': 28,
#  '고': 29,
#  'ㄴ가요': 30,
#  '이것': 31,
#  '가격': 32,
#  '죠': 33,
#  '색상': 34,
#  '안': 35,
#  '원': 36,
#  '아요': 37,
#  '그럼': 38,
#  '는데요': 39,
#  '것': 40,
#  '취소': 41,
#  '면': 42,
#  'ㄹ': 43,
#  '어떻': 44,
#  '제가': 45,
#  '를': 46,
#  '없': 47,
#  '맞': 48,
#  '어': 49,
#  '오': 50,
#  '으로': 51,
#  '아서': 52,
#  '로': 53,
#  '아니': 54,
#  '도': 55,
#  '그러면': 56,
#  '지금': 57,
#  '려고요': 58,
#  '겠': 59,
#  '만': 60,
#  '뭐': 61,
#  '할인': 62,
#  '받': 63,
#  '그': 64,
#  '상품': 65,
#  '나오': 66,
#  '크': 67,
#  'ㄹ려고': 68,
#  '같': 69,
#  '옷': 70,
#  '에요': 71,
#  '그냥': 72,
#  '아야': 73,
#  '었': 74,
#  '수': 75,
#  '그것': 76,
#  '보': 77,
#  '려고': 78,
#  '네요': 79,
#  '예요': 80,
# ...
